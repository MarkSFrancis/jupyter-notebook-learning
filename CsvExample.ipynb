# %%
import pandas

# %%
sample_data = pandas.read_csv('sample-data.csv')

# %%
sample_data
# Out:
#     Rank             City  Population                          Definition  \
# 0      1        Chongqing  30,165,500                        Municipality
# 1      2         Shanghai  24,183,300                        Municipality
# 2      3          Beijing  21,707,000                        Municipality
# 3      4         Istanbul  15,029,231           Metropolitan municipality
# 4      5          Karachi  14,910,352                                City
# 5      6            Dhaka  14,399,000                        Capital city
# 6      7            Tokyo  13,515,271                        Capital city
# 7      8           Moscow  13,200,000                        Federal city
# 8      9        Guangzhou  13,081,000                City(sub-provincial)
# 9     10         Shenzhen  12,528,300                City(sub-provincial)
# 10    11           Mumbai  12,442,373                                City
# 11    12         So Paulo  12,038,000                        Municipality
# ...
